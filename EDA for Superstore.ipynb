# %% [markdown]
# By: Mostafa Mahmoud Hassan
# Data Science and business Analytics Internship [septamper 2022]
# Task 3: Exploratory Data Analysis - Retail

# %% [markdown]
# # Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
data=pd.read_csv('SampleSuperstore.csv')
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Exploring the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data['City'].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# Our stores are distributed over 531 cities,and new york city is the city with the most stores

# %%
data['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# Our stores are distributed over 39 state,and California state has the most stores

# %%
data['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# Our stores are distributed over 4 region,and the west region has the most stores

# %%
sns.countplot(data['Region'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# the most category we have is Office Supplies Category

# %%
sns.countplot(data['Sub-Category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# the most sub-category we have is Binders then papers

# %%
data.groupby('Category')['Quantity'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# Office Supplies is the Most selling category

# %%
data.groupby('Sub-Category')['Quantity'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# Binders is the Most selling Sub-category then Paper

# %%
category_profit=data.groupby('Category')['Profit'].sum()
category_profit
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
plt.pie(category_profit,labels=data['Category'].unique())
plt.title('Profit per Category')
plt.legend()
plt.show()

# %% [markdown]
# Technology is the Most profitable Category
# Furniture id the least profitable Category

# %%
data.groupby('City')['Profit'].sum().nlargest(10)
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Lafayette        10018.3876
# Jackson           7581.6828
# Atlanta           6993.6629
# Minneapolis       6824.5846
# San Diego         6377.1960
# Name: Profit, dtype: float64

# %%
profit=data['Profit']>0.0

# %%
most_10_cities_gain=data[profit].groupby('City').sum().sort_values(by='Profit',ascending=False).head(10)
most_10_cities_gain
# Out:
#                Postal Code       Sales  Quantity  Discount      Profit
# City
# New York City      8697921  234654.729      3257     39.20  66003.0063
# Los Angeles       63471667  160363.606      2723     47.60  31611.0879
# Seattle           39831426  113956.790      1516     24.40  29541.2676
# San Francisco     45363161   99342.638      1839     28.85  18849.1535
# Detroit            5545741   42446.944       441      0.80  13181.7908
# Lafayette          1866569   25030.260       101      0.00  10018.3876
# Springfield        7131527   37031.214       520      8.80   9368.9202
# Newark             2129870   23921.522       313      4.40   8970.5590
# Columbus           6757311   29384.446       636     14.20   7914.9880
# Jackson            3509254   23819.334       310      1.90   7854.5808

# %%
data.groupby('City')['Profit'].sum().nlargest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# New York City is the Most profitable City

# %%
#averge of profit
data['Profit'].mean()
# Out:
# 28.656896307784802

# %%
data.groupby('City')['Profit'].sum().nsmallest(10)
# Out:
# City
# Philadelphia   -13837.7674
# Houston        -10153.5485
# San Antonio     -7299.0502
# Lancaster       -7239.0684
# Chicago         -6654.5688
# Burlington      -3622.8772
# Dallas          -2846.5257
# Phoenix         -2790.8832
# Aurora          -2691.7386
# Jacksonville    -2323.8350
# Name: Profit, dtype: float64

# %%
data.groupby('City')['Profit'].sum().nsmallest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# Philadelphia is the Most lost cities

# %%
profitcategory=data[profit].groupby(['Category']).sum().sort_values(by='Profit',ascending=False)
profitcategory
# Out:
#                  Postal Code        Sales  Quantity  Discount       Profit
# Category
# Technology          88840888  716701.1480      5957    153.80  184034.8663
# Office Supplies    280764675  618988.7490     19370    400.40  179106.0593
# Furniture           73713750  465116.9615      5251     98.85   79387.3818

# %%
gain_per_category_AND_region=data[profit].groupby(['Category','Region','Sub-Category']).sum()
gain_per_category_AND_region
# Out:
#                                  Postal Code      Sales  Quantity  Discount  \
# Category   Region  Sub-Category
# Furniture  Central Bookcases          711257   5381.020        44       0.0
#                    Chairs            2929768  44095.020       233       0.0
#                    Furnishings       3666181   8609.670       257       0.0
#                    Tables            1251204  17332.870        81       0.3
#            East    Bookcases          369168  25262.890       125       3.4
# ...                                      ...        ...       ...       ...
# Technology South   Phones            4441542  57751.022       484      13.0
#            West    Accessories      22074537  58792.628       949       5.6
#                    Copiers           2272619  49749.242        88       3.6
#                    Machines          2883869  37954.568       117       6.2
#                    Phones           22673134  95847.344       974      49.8
#
# ...

# %%
no_profit=data['Profit']<0.0

# %%
#Cities_with_no_profits
data[no_profit].groupby('City').sum().sort_values(by='Profit')
#data.groupby('City')['Profit'].sum()<=0
# Out:
#               Postal Code       Sales  Quantity  Discount      Profit
# City
# Philadelphia      4783713  70460.5510       892    115.30 -19590.7411
# Houston          14256474  37640.7304       683    104.14 -14785.3668
# Chicago           9397492  19910.0120       541     88.20 -11120.6271
# San Antonio       2580831  17395.1450       139     17.10  -7831.0254
# Lancaster          683904   7699.2420        71      9.40  -7632.4946
# ...                   ...         ...       ...       ...         ...
# Loveland           161076      4.2120         5      0.90     -1.5948
# Pensacola           32503      2.2140         3      0.70     -1.4760
# Elyria              44035      1.8240         1      0.70     -1.3984
# Homestead           33030      2.9440         1      0.20     -0.6624
# Coppell             75019     16.7840         1      0.20     -0.2098
#
# [229 rows x 5 columns]

# %%
most_10_cities_lost=data[no_profit].groupby('City').sum().sort_values(by='Profit').head(10)
most_10_cities_lost
# Out:
#                Postal Code       Sales  Quantity  Discount      Profit
# City
# Philadelphia       4783713  70460.5510       892    115.30 -19590.7411
# Houston           14256474  37640.7304       683    104.14 -14785.3668
# Chicago            9397492  19910.0120       541     88.20 -11120.6271
# San Antonio        2580831  17395.1450       139     17.10  -7831.0254
# Lancaster           683904   7699.2420        71      9.40  -7632.4946
# Burlington          108868  12044.8740        19      2.00  -5999.3318
# Dallas             5487794   9994.0562       280     39.30  -4208.5218
# Jacksonville       1237176  31146.2710       154     18.85  -4059.9857
# New York City       400828  19533.8020       132     12.20  -3966.0226
# Louisville          640216   2884.7840        35      4.90  -3694.1045

# %%
lost_per_category_AND_region=data[no_profit].groupby(['Category','Region']).sum()
lost_per_category_AND_region
# Out:
#                          Postal Code       Sales  Quantity  Discount  \
# Category        Region
# Furniture       Central     22429781  85278.5008      1179    140.64
#                 East         4219797  87079.1600       663     60.90
#                 South        1917716  30742.0380       240     17.55
#                 West        14059154  54785.8880       570     43.05
# Office Supplies Central     26864339  33072.5080      1455    255.00
#                 East         6799519  27642.0250       843    132.10
#                 South        5581410  20402.7810       659    100.00
#                 West         9259738  10491.3610       468     60.10
# Technology      Central      3574279  22931.6500       169     11.50
#                 East         4110635  46142.8270       482     54.10
#                 South        1012656  40490.3660       105      9.80
#                 West         4930367   9648.0500       207     15.00
#
#                              Profit
# ...

# %%
lost_per_SubCategory_AND_region=data[no_profit].groupby(['Category','Region','Sub-Category']).sum()
lost_per_SubCategory_AND_region
# Out:
#                                       Postal Code       Sales  Quantity  \
# Category        Region  Sub-Category
# Furniture       Central Bookcases         2619171  18577.4128       144
#                         Chairs            6664009  38791.8720       358
#                         Furnishings       9679598   6644.7000       501
#                         Tables            3467003  21264.5160       176
#                 East    Bookcases          699790  18556.4440       127
#                         Chairs            1611272  26163.3440       219
#                         Furnishings        462638   3910.2480        51
#                         Tables            1446097  38449.1240       266
#                 South   Bookcases          253552   2598.3520        33
#                         Chairs             541300   5672.0320        56
#                         Furnishings        234197   1090.5920        23
# ...

# %%
lostcategory=data[no_profit].groupby(['Category']).sum()
lostcategory
# Out:
#                  Postal Code        Sales  Quantity  Discount      Profit
# Category
# Furniture           42626448  257885.5868      2652    262.14 -60936.1090
# Office Supplies     48505006   91608.6750      3425    547.20 -56615.2585
# Technology          13627937  119212.8930       963     90.40 -38579.9182

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=data,x='Profit',y='Discount')
plt.title('RelationShip between Profit and Discount')
plt.show()

# %% [markdown]
# we note that there is a relathion between profit and discount,
# the discount is the reason for lost money, more discount less profits

# %%
plt.figure(figsize=(8,5))
data.groupby('Category')['Profit','Sales'].agg('sum').plot.bar()
plt.ylabel('profit & sales')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_15196/2346984960.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Category')['Profit','Sales'].agg('sum').plot.bar()

# %% [markdown]
# We note that technology is the most selling and profitable
